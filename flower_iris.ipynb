# %% [markdown]
# <a href="https://colab.research.google.com/github/archit-8/interngrow/blob/main/flower_iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %% [markdown]
# project : Iris Flowers Classification ML Project

# %% [markdown]
# importing important package

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set_palette('husl')
import os

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import  train_test_split
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn .metrics import classification_report
from sklearn.metrics import accuracy_score

# %% [markdown]
# loading data from url

# %%
url=('https://raw.githubusercontent.com/jbrownlee/Datasets/master/iris.csv')

# %%
col_name=['sepal-length', 'sepal-width','petal-lenght','petal-width','class']

# %%
dataset= pd.read_csv(url, names=col_name)

# %% [markdown]
# Summarizing the Dataset

# %%
dataset.shape
# Out:
# (150, 5)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal-length  150 non-null    float64
#  1   sepal-width   150 non-null    float64
#  2   petal-lenght  150 non-null    float64
#  3   petal-width   150 non-null    float64
#  4   class         150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
dataset.describe()
# Out:
#        sepal-length  sepal-width  petal-lenght  petal-width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
dataset['class'].value_counts()
# Out:
# Iris-versicolor    50
# Iris-setosa        50
# Iris-virginica     50
# Name: class, dtype: int64

# %% [markdown]
# Data Visualization

# %%
sns.violinplot(y='class',x='sepal-length',data=dataset,inner='quartile')
plt.show()
sns.violinplot(y='class',x='sepal-width',data=dataset,inner='quartile')
plt.show()
sns.violinplot(y='class',x='petal-lenght',data=dataset,inner='quartile')
plt.show()
sns.violinplot(y='class',x='petal-width',data=dataset,inner='quartile')
plt.show()

# %%
sns.violinplot(y='class',x='sepal-length',data=dataset,inner='quartile')
sns.violinplot(y='class',x='sepal-width',data=dataset,inner='quartile')
sns.violinplot(y='class',x='petal-lenght',data=dataset,inner='quartile')
sns.violinplot(y='class',x='petal-width',data=dataset,inner='quartile')

# %% [markdown]
# pairplot

# %%
sns.pairplot(dataset,hue ='class', markers='+')
plt.show()

# %% [markdown]
# heatmap

# %%
plt.figure(figsize=(7,5))
sns.heatmap(dataset.corr(), annot=True, cmap='cubehelix_r')
plt.show()

# %% [markdown]
# Model Building

# %% [markdown]
# Splitting the dataset

# %%
x =dataset[['sepal-length', 'sepal-width','petal-lenght','petal-width']]
y=dataset['class']

# %% [markdown]
# Train Test split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25,random_state=28)

# %% [markdown]
# Logistic Regression (LR):
# logestic regression algorithm is used to predict the probability of a target variable

# %%
model1=LogisticRegression()
model1.fit(x_train,y_train)
y_pred=model.predict(x_test)
print("accuracy of the logestic regsettion classifier on the test set :{:f}" .format(model.score(x_test,y_test)))
# Out:
# accuracy of the logestic regsettion classifier on the test set :0.947368

# %% [markdown]
# test set

# %%
print(classification_report(y_test,y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        11
# Iris-versicolor       1.00      0.87      0.93        15
#  Iris-virginica       0.86      1.00      0.92        12
#
#        accuracy                           0.95        38
#       macro avg       0.95      0.96      0.95        38
#    weighted avg       0.95      0.95      0.95        38

# %% [markdown]
# spelting accarcy score

# %%
train_score=str(model1.score(x_train,y_train)*100)
test_score=str(model1.score(x_test,y_test)*100)
accu_score=str(accuracy_score(y_test,y_pred)*100)
print(f'Train score : {train_score[0:6]}')
print(f'test score :{test_score[:6]}')
print(f'accuracy score : {accu_score[:6]}')
# Out:
# Train score : 98.214
# test score :94.736
# accuracy score : 94.736
